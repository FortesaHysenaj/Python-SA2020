# %%
# !pip install -U scikit-learn
# Out:
# Requirement already up-to-date: scikit-learn in c:\users\twin\anaconda3\lib\site-packages (0.23.2)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in c:\users\twin\anaconda3\lib\site-packages (from scikit-learn) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in c:\users\twin\anaconda3\lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in c:\users\twin\anaconda3\lib\site-packages (from scikit-learn) (0.14.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in c:\users\twin\anaconda3\lib\site-packages (from scikit-learn) (2.1.0)

# %%
import sklearn 
from sklearn import metrics
from sklearn.cluster import KMeans #allows us to perform K-means clustering

import pandas as pd
import numpy as np #for data wrangling
import matplotlib #for visualization
import matplotlib.pyplot as plt

import random

import warnings
warnings.filterwarnings("ignore") #turned off warnings

# %%
print(sklearn.__version__)
# Out:
# 0.23.2

# %%
print(np.__version__)
# Out:
# 1.18.1

# %%
print(pd.__version__)
# Out:
# 1.0.1

# %%
data_1 = np.array([[random.randint(1, 400) for i in range(2)] for j in range(50)], 
                       dtype=np.float64)

data_2 = np.array([[random.randint(300, 700) for i in range(2)] for j in range(50)], 
                       dtype=np.float64)

data_3 = np.array([[random.randint(600, 900) for i in range(2)] for j in range(50)], 
                       dtype=np.float64)

data = np.append(np.append(data_1, data_2, axis=0), data_3, axis=0)

# %%
data.shape
# Out:
# (150, 2)

# %%
fig, ax = plt.subplots(figsize=(12, 8))

plt.scatter(data[:,0], data[:,1], s=200)
